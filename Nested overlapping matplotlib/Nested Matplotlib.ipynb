# %% [markdown]
# # Nested matplotlib

# %%
import matplotlib.pyplot as plt

# %%
fig, ax1 = plt.subplots()

ax2 = fig.add_axes([.25,.6,.2,.2])

ax1.plot(range(10),color='red')

img = plt.imread("zemmour.jpg")
ax2.imshow(img, extent=[0,120,0,80])
ax2.plot(range(6)[::-1],color='green')
ax2.set_title("hello")
# Out:
# Text(0.5, 1.0, 'hello')

# %%
a = range(10)
print(a)
# Out:
# range(0, 10)
