# %% [markdown]
# # Bivariate Plotting with Pandas

# %% [markdown]
# * Scatter Plot
# * Hex Plot
# * Stacked Bar Plot
# * Bivariate Line Chart

# %% [markdown]
# <img src='bivariate_plotting.png'>

# %%
from IPython.display import Image
Image(filename="bivariate_plotting.png")

# %%
import pandas
# %matplotlib inline

# %%
import pandas as pd
reviews = pd.read_csv("Dataset/winemag-data_first150k.csv", index_col=0)
reviews.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %% [markdown]
# ## Scatter Plot

# %% [markdown]
# 2-dimensional data visualization representing values obtained with the help of 2 variables (x and y).
# * Relationship between 2 variables
# * also called correlation plots

# %%
#prendre un plus petit échatillon de données pour éviter la confusion et la superposition des données
reviews[reviews['price'] < 100].sample(100).plot.scatter(x='price',y='points')

# %%
#sans échantillonage
reviews[reviews['price'] < 100].plot.scatter(x='price',y='points')

# %% [markdown]
# # Hexplot

# %% [markdown]
# Close to a scatter plot, shows a sort of heat map of the data and is useful in case of **overlapping**

# %%
reviews[reviews['price'] < 100].plot.hexbin(x='price', y='points', gridsize=15)

# %% [markdown]
# ## Stacked Plot

# %% [markdown]
# Helpful with categorical data
# * Part to whole relationship
# * used if the total of parts is crucial for better comparison
# * They work best for nominal categorical or small ordinal categorical variables.
# * (-) not very precise for interpretability
# * (-) the number of values should be limited for better readability

# %%
wine_counts = pd.read_csv('Dataset/top-five-wine-score-counts.csv',index_col=0)

# %%
wine_counts
# Out:
#         Bordeaux-style Red Blend  Cabernet Sauvignon  Chardonnay  Pinot Noir  \
# points
# 80                           5.0                87.0        68.0        36.0
# 81                          18.0               159.0       150.0        83.0
# 82                          72.0               435.0       517.0       295.0
# 83                          95.0               570.0       669.0       346.0
# 84                         268.0               923.0      1146.0       733.0
# 85                         310.0              1048.0      1244.0       873.0
# 86                         354.0              1194.0      1472.0      1218.0
# 87                         510.0              1566.0      1809.0      1726.0
# 88                         498.0              1141.0      1416.0      1474.0
# 89                         433.0               908.0       969.0      1154.0
# 90                         557.0              1329.0      1353.0      1550.0
# ...

# %% [markdown]
# Comparison of points repartition for the 5 different wines :

# %%
wine_counts.plot.bar(stacked=True)

# %% [markdown]
# Area Chart version :

# %%
wine_counts.plot.area()

# %% [markdown]
# ## Bivariate line chart

# %% [markdown]
# much more interpretable than the stacked plot version

# %%
wine_counts.plot.line()
